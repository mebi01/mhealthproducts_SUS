# %%
library("tidyverse")
library("ggplot2")
library('magrittr')
library('ggpubr')
library("dplyr")
#library("dlookr")
library("psych") # describe function
library("purrr") # keep function
# Out:
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.2.1       ✔ purrr   0.3.2
# ✔ tibble  2.1.1       ✔ dplyr   0.8.0.1
# ✔ tidyr   0.8.3       ✔ stringr 1.4.0
# ✔ readr   1.3.1       ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Attaching package: ‘magrittr’
#
# The following object is masked from ‘package:purrr’:
#
#     set_names
#
# The following object is masked from ‘package:tidyr’:
#
#     extract
#
#
# Attaching package: ‘psych’
#
# The following objects are masked from ‘package:ggplot2’:
#
#     %+%, alpha

# %%
df<- read.table(pipe("pbpaste"), sep= "\t", header= T)

# %%
head(df)
# Out:
#   Users Product frequent_use complex easy_to_use need_help well.integrated
# 1 u32   Coach   5            -2      3           -2        NA
# 2 u17   Coach   4            -2      4           -1         3
# 3 u50   Coach   4            -1      2           -1         3
# 4 u12   Coach   4            -1      3           -1         3
# 5 u59   Coach   4            -1      4           -1         4
# 6 u122  Beyond  4            -1      4           -1         3
#   inconsistent learnable cumbersome ... need_knowledge total_score signUp
# 1 -2           NA         0         ...  0              2          215
# 2 -2            4        -2         ... -2             10          209
# 3 -1            2        -1         ... -5              4          208
# 4 -1            4        -2         ... -1             11          207
# 5 -1            2        -2         ... -1              9          205
# 6 -1            4        -2         ... -3             11          204
# ...

# %%
str(df)
# Out:
# 'data.frame':	187 obs. of  21 variables:
#  $ Users                : Factor w/ 187 levels "u1","u10","u100",..: 114 49 134 23 143 25 106 83 29 181 ...
#  $ Product              : Factor w/ 3 levels "Advocate","Beyond",..: 3 3 3 3 3 2 2 3 3 1 ...
#  $ frequent_use         : int  5 4 4 4 4 4 2 3 2 2 ...
#  $ complex              : int  -2 -2 -1 -1 -1 -1 -1 -3 -2 -1 ...
#  $ easy_to_use          : int  3 4 2 3 4 4 4 4 4 4 ...
#  $ need_help            : int  -2 -1 -1 -1 -1 -1 -1 -2 -2 -1 ...
#  $ well.integrated      : int  NA 3 3 3 4 3 3 3 3 4 ...
#  $ inconsistent         : int  -2 -2 -1 -1 -1 -1 -1 -3 -2 -1 ...
#  $ learnable            : int  NA 4 2 4 2 4 5 4 3 4 ...
#  $ cumbersome           : int  0 -2 -1 -2 -2 -2 -1 -3 -5 -1 ...
#  $ confident            : int  NA 4 2 3 1 4 4 4 3 4 ...
#  $ need_knowledge       : int  0 -2 -5 -1 -1 -3 -3 -3 -2 -1 ...
#  $ total_score          : int  2 10 4 11 9 11 11 4 2 13 ...
#  $ signUp               : num  215 209 208 207 205 ...
# ...

# %%
describe(df)
# Out:
#                       vars n   mean       sd         median trimmed    mad
# Users*                 1   187  94.000000 54.1263953  94.00  94.000000 69.68220
# Product*               2   187   2.069519  0.7900465   2.00   2.086093  1.48260
# frequent_use           3   187   3.770053  0.9364549   4.00   3.860927  0.00000
# complex                4   187  -1.614973  0.9224735  -1.00  -1.456954  0.00000
# easy_to_use            5   186   4.473118  5.2496412   4.00   3.860000  0.00000
# need_help              6   187  -1.572193  0.8668798  -1.00  -1.417219  0.00000
# well.integrated        7   186   3.763441  3.1154293   3.00   3.553333  0.00000
# inconsistent           8   187  -1.946524  3.2224559  -1.00  -1.635762  0.00000
# learnable              9   186   4.075269  0.9327270   4.00   4.186667  1.48260
# cumbersome            10   187  -1.443850  0.6564831  -1.00  -1.364238  0.00000
# confident             11   185   4.016216  0.9468235   4.00   4.134228  1.48260
# ...

# %%
?geom_bar

# %%
# let simply look at two numerical varaible
ggplot(df)+ 
geom_point(mapping= aes(x=signUp, y=signIn))
# Out:
# plot without title

# %%
# let simply look at two numerical varaible
ggplot(df)+ 
geom_point(mapping= aes(x=signUp, y=signIn, color= Product))
# Out:
# plot without title

# %%
ggplot(df)+ 
geom_point(mapping= aes(x=signUp, y=signIn, color= Product, size= completeTask))
# Out:
# Warning message:
# “Using size for a discrete variable is not advised.”
# plot without title

# %% [markdown]
# To facet your plot by a single variable, use facet_wrap(). The first argument of facet_wrap() should be a formula, which you create with ~ followed by a variable name (here “formula” is the name of a data structure in R, not a synonym for “equation”). The variable that you pass to facet_wrap() should be discrete.

# %%
ggplot(df)+
geom_point(mapping= aes(x= signUp, y=signIn, color= Product))+
facet_wrap( ~completeTask, nrow=1)
# Out:
# plot without title

# %%
ggplot(df)+
geom_point(mapping= aes(x= signUp, y=signIn, color= completeTask))+
facet_wrap(~Product)
# Out:
# plot without title

# %%
#if want to facet more than single var, use facet_grid
ggplot(df) +
geom_point(mapping= aes(x= signUp, y=signIn, color=completeTask))+ 
facet_grid(Product ~ confident)
# Out:
# plot without title

# %% [markdown]
# A geom is the geometrical object that a plot uses to represent data. People often describe plots by the type of geom that the plot uses. For example, bar charts use bar geoms, line charts use line geoms, boxplots use boxplot geoms, and so on. Scatterplots break the trend; they use the point geom. As we see above, you can use different geoms to plot the same data. The plot on the left uses the point geom, and the plot on the right uses the smooth geom, a smooth line fitted to the data.

# %%
ggplot(df)+
geom_smooth(mapping= aes(x= signUp, y=signIn, color= Product))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(df)+
geom_smooth(mapping= aes(x= signUp, y=signIn, linetype= Product))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(df)+
geom_smooth(mapping= aes(x= signUp, y=signIn))+
facet_wrap(~Product, nrow= 2)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(df)+
geom_smooth(mapping= aes(x= signUp, y=signIn, color= Product))+

geom_point(mapping= aes(x= signUp, y=signIn))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
# do not need to write x and y in mapping
ggplot(df)+
geom_smooth(mapping= aes(signUp, signIn))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
# you can also write mapping inside of ggplot as a general informaiton
ggplot(df, mapping= aes(signUp, signIn))+
geom_smooth()+
geom_point(mapping= aes(color= Product))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
# we can aslo combine the code with filter to subset and plot part of data
# eg. consider when we just want to get smooth plot line only when signup time is more than 100s

ggplot(df, mapping=aes(signUp, signIn))+
geom_point()+
geom_smooth(data= filter(df, df$signUp > 100), mapping= aes(color= 'red'))+
geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
#othe play
ggplot(df, mapping= aes(signUp, signIn))+
#geom_point(mapping= aes(size= Product, color= completeTask))+
#geom_line(data= filter(df, df$total_score<5), mapping= aes(color= completeTask))+
geom_smooth(data= filter(df, df$total_score<5), mapping= aes(color= completeTask))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “span too small.   fewer data values than degrees of freedom.”Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at 105.45”Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 93.595”Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  0”Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “There are other near singularities as well. 272.09”Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# ...

# %% [markdown]
#  transformation

# %%
ggplot(df)+
geom_bar(mapping= aes(completeTask, fill=completeTask ))+
facet_wrap(~Product )
# Out:
# plot without title

# %%
#other way
barplot(table(df$completeTask, by= df$Product), col= c("red", "blue"))
# Out:
# plot without title

# %%
#other way to barbplot the data
ggplot(df)+
stat_count(mapping= aes(df$completeTask))
# Out:
# plot without title

# %%
# get prop instead of freq
ggplot(df)+
stat_summary(
    mapping= aes(x= completeTask, y=total_score),
)
# Out:
# No summary function supplied, defaulting to `mean_se()
# plot without title

# %%
# position = "dodge" places overlapping objects directly beside one another. This makes it easier to compare individual values.

ggplot(df)+
geom_bar(mapping= aes(completeTask, fill= Product), position = "fill")


ggplot(df)+
geom_bar(mapping= aes(completeTask, fill= Product), position = "dodge")
# Out:
# plot without title
# plot without title

# %% [markdown]
# You can avoid this gridding by setting the position adjustment to “jitter”. position = "jitter" adds a small amount of random noise to each point. This spreads the points out because no two points are likely to receive the same amount of random noise.

# %%
ggplot(df)+
geom_point(mapping= aes(signUp, total_score), position = "jitter")
# Out:
# plot without title

# %% [markdown]
# boxplot

# %%
ggplot(df)+
geom_boxplot(mapping= aes(completeTask, signUp))

#or 

ggplot(df, mapping= aes(completeTask, signUp))+
geom_boxplot(mapping= aes(color= completeTask))
# Out:
# plot without title
# plot without title

# %%
# use coord_flip to rotate the plot
ggplot(df, mapping= aes(completeTask, signUp))+
geom_boxplot(mapping= aes(fill= Product))+
coord_flip()
# Out:
# plot without title

# %%
# how to hide legend
p1<- ggplot(df, mapping= aes(signIn, signUp))+
    geom_point()+
    geom_abline()
p1
# Out:
# plot without title

# %%
p1+ coord_flip()
# Out:
# plot without title

# %%
# density plot
par(mfrow = c(1,2))
plot(density(df$signUp), main= "Density plot for sign up" , col="blue")
plot(density(df$signIn), main= "Density plot for sign In", col="grey")
# Out:
# Plot with title “Density plot for sign In”

# %%
# how to check normality of all variables
# use gather to create a two col of all varaibles

df %>% keep(is.numeric) %>% gather() %>%
ggplot(mapping= aes(value)) +
facet_wrap(~key, scales = "free") +
geom_density(fill= "grey")
# Out:
# Warning message:
# “Removed 5 rows containing non-finite values (stat_density).”
# plot without title

# %%
plot(df[13:15] , cex = 1.5, col = "dark red")
# Out:
# plot without title

# %%
plot(df[3:12])
# Out:
# plot without title

# %%
# creat a variable based on total score, if total score is more less than 10 or not and then categorize it as factor and plot it

df$cat_totalScore <- sapply(df$total_score, function(x) ifelse(x<10, "LessThan5", "MoreThan5"))

# %%
ggplot(df)+
geom_bar(mapping= aes(df$cat_totalScore, fill= df$Product), position = "fill")
# Out:
# plot without title

# %%
str(df) # make sure yoy use sapply instead of lapply
# Out:
# 'data.frame':	187 obs. of  22 variables:
#  $ Users                : Factor w/ 187 levels "u1","u10","u100",..: 114 49 134 23 143 25 106 83 29 181 ...
#  $ Product              : Factor w/ 3 levels "Advocate","Beyond",..: 3 3 3 3 3 2 2 3 3 1 ...
#  $ frequent_use         : int  5 4 4 4 4 4 2 3 2 2 ...
#  $ complex              : int  -2 -2 -1 -1 -1 -1 -1 -3 -2 -1 ...
#  $ easy_to_use          : int  3 4 2 3 4 4 4 4 4 4 ...
#  $ need_help            : int  -2 -1 -1 -1 -1 -1 -1 -2 -2 -1 ...
#  $ well.integrated      : int  NA 3 3 3 4 3 3 3 3 4 ...
#  $ inconsistent         : int  -2 -2 -1 -1 -1 -1 -1 -3 -2 -1 ...
#  $ learnable            : int  NA 4 2 4 2 4 5 4 3 4 ...
#  $ cumbersome           : int  0 -2 -1 -2 -2 -2 -1 -3 -5 -1 ...
#  $ confident            : int  NA 4 2 3 1 4 4 4 3 4 ...
#  $ need_knowledge       : int  0 -2 -5 -1 -1 -3 -3 -3 -2 -1 ...
#  $ total_score          : int  2 10 4 11 9 11 11 4 2 13 ...
#  $ signUp               : num  215 209 208 207 205 ...
# ...

# %%
# other way to categorize a variable , be aware that it does not save this new variable.
df %>% mutate(test_cat= sapply(df$total_score, function (x) ifelse (x <5, "Yes", "No")))
# Out:
#     Users Product  frequent_use complex easy_to_use need_help well.integrated
# 1   u32   Coach    5            -2      3           -2        NA
# 2   u17   Coach    4            -2      4           -1         3
# 3   u50   Coach    4            -1      2           -1         3
# 4   u12   Coach    4            -1      3           -1         3
# 5   u59   Coach    4            -1      4           -1         4
# 6   u122  Beyond   4            -1      4           -1         3
# 7   u258  Beyond   2            -1      4           -1         3
# 8   u22   Coach    3            -3      4           -2         3
# 9   u13   Coach    2            -2      4           -2         3
# 10  u93   Advocate 2            -1      4           -1         4
# 11  u28   Coach    4            -1      4           -1         4
# 12  u161  Beyond   4            -3      4           -1         3
# 13  u215  Beyond   4            -2      4           -2         5
# ...

# %%
head(df)
# Out:
#   Users Product frequent_use complex easy_to_use need_help well.integrated
# 1 u32   Coach   5            -2      3           -2        NA
# 2 u17   Coach   4            -2      4           -1         3
# 3 u50   Coach   4            -1      2           -1         3
# 4 u12   Coach   4            -1      3           -1         3
# 5 u59   Coach   4            -1      4           -1         4
# 6 u122  Beyond  4            -1      4           -1         3
#   inconsistent learnable cumbersome ... total_score signUp signIn firstClick
# 1 -2           NA         0         ...  2          215    139.13 55.00
# 2 -2            4        -2         ... 10          209    116.13 16.97
# 3 -1            2        -1         ...  4          208    131.00 50.00
# 4 -1            4        -2         ... 11          207     85.05 46.00
# 5 -1            2        -2         ...  9          205    135.13 16.05
# 6 -1            4        -2         ... 11          204    135.00 31.00
# ...

# %%
ggplot(df) +
geom_bar (mapping= aes(x= reorder (df$cat_totalScore, df$total_score), fill=df$Product))
# Out:
# plot without title

# %%
?geom_bar

# %%
# other way to get facet for data
par(mfrow = c(1, 3))
with(subset(df, Product== "Advocate"), plot(signUp, signIn)) 
with(subset(df, Product== "Beyond"), plot(signUp, signIn))
with(subset(df, Product== "Coach"), plot(signUp, signIn))
# Out:
# plot without title

# %% [markdown]
# # The Complete ggplot2 Tutorial - Part 2 | How To Customize ggplot2

# %%
par (mfrow = c(1,2))
p1<- ggplot(df, aes(signIn, signUp)) + 
geom_point(aes(col=df$Product, size=df$cat_totalScore))+ geom_smooth( method= "loess", se= F)+
labs(title = "SignUp-SignIn", x= "Sign In", y= "Sign Up")

p1
# Out:
# Warning message:
# “Using size for a discrete variable is not advised.”
# plot without title

# %%
# More modification? Modifying theme of plot
theme_set(theme_bw())

par (mfrow = c(1,2))
p1<- ggplot(df, aes(signIn, signUp)) + 
geom_point(aes(col=df$Product, size=df$cat_totalScore))+ geom_smooth( method= "loess", se= F)+
labs(title = "SignUp-SignIn", x= "Sign In", y= "Sign Up")

p1 + theme(plot.title =element_text (color = "red", size= 18, face= "bold", hjust =.9, vjust = .1, lineheight = 4 ),
           axis.title.x= element_text(color= "green", size= 22))
# Out:
# Warning message:
# “Using size for a discrete variable is not advised.”
# plot without title

# %% [markdown]
# ### how to modify legend

# %%
#base plot
p2<- ggplot(df, aes(signIn, signUp)) + 
geom_point(aes(col=df$Product, size=df$cat_totalScore))+ geom_smooth( method= "loess", se= F)+
labs(title = "SignUp-SignIn", x= "Sign In", y= "Sign Up")

#based on which variable color and size correpsond for
p2+ guides(color=guide_legend("Product"), size= guide_legend("Categor of total score"))
# Out:
# Warning message:
# “Using size for a discrete variable is not advised.”
# plot without title

# %%
# what if we want to change the item of legend?
p3<- ggplot(df, aes(signIn, signUp)) + 
geom_point(aes(col=df$Product, size=df$cat_totalScore))+ geom_smooth( method= "loess", se= F)+
labs(title = "SignUp-SignIn", x= "Sign In", y= "Sign Up")

# scale_color_manual
p3 + guides(color=guide_legend("Product"), size= guide_legend("Categor of total score")) +
     scale_color_manual (name= "Product", labels= c("App Advocate", "App Beyond", "App Coach"),
                        values = c("Advocate"="blue", "Beyond"="red", "Coach"="green"))
# Out:
# Warning message:
# “Using size for a discrete variable is not advised.”
# plot without title

# %%
# change the order of legend? use order()
p4<- ggplot(df, aes(signIn, signUp)) + 
geom_point(aes(col=df$Product, size=df$cat_totalScore))+ geom_smooth( method= "loess", se= F)+
labs(title = "SignUp-SignIn", x= "Sign In", y= "Sign Up")

# scale_color_manual
p4 + guides(colour=guide_legend( order = 2), size= guide_legend(order=1))
# Out:
# Warning message:
# “Using size for a discrete variable is not advised.”
# plot without title

# %% [markdown]
# # many more about legend and changing in plot
# https://r-statistics.co/Complete-Ggplot2-Tutorial-Part2-Customizing-Theme-With-R-Code.html
